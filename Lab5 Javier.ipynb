# %%
from pathlib import Path

student_id = "2025-1117"
student_name = "Javier"

documents_path = Path.home() / "Documents" / "Activity_5_Files"
documents_path.mkdir(parents=True, exist_ok=True)

file_path = documents_path / f"intro_{student_id}.txt"

file_path.write_text(
    f"Welcome {student_name} (ID: {student_id}) to File Handling in Python!"
)

print(f"File created and text written at: {file_path}")
# Out:
# File created and text written at: C:\Users\japhe\Documents\Activity_5_Files\intro_2025-1117.txt

# %%
from pathlib import Path

student_id = "2025-1117"
student_name = "Javier"

documents_path = Path.home() / "Documents" / "Activity_5_Files"
file_path = documents_path / f"intro_{student_id}.txt"

content = file_path.read_text()
print(content)
# Out:
# Welcome Javier (ID: 2025-1117) to File Handling in Python!

# %%
from pathlib import Path

student_id = "2025-1117"

file_path = Path.home() / "Documents" / "Activity_5_Files" / f"intro_{student_id}.txt"

with file_path.open("a") as f:
    f.write("\nThis is a new line.")

print(f"Line appended to: {file_path}")
# Out:
# Line appended to: C:\Users\japhe\Documents\Activity_5_Files\intro_2025-1117.txt

# %%
from pathlib import Path

student_id = "2025-1117"

documents_path = Path.home() / "Documents" / "Activity_5_Files"
file_path = documents_path / f"lines_{student_id}.txt"

lines = ["Line 1", "Line 2", "Line 3"]

with file_path.open("w") as f:
    f.write("\n".join(lines))

print(f"Multiple lines written to: {file_path}")
# Out:
# Multiple lines written to: C:\Users\japhe\Documents\Activity_5_Files\lines_2025-1117.txt

# %%
from pathlib import Path

student_id = "2025-1117"

file_path = Path.home() / "Documents" / "Activity_5_Files" / f"lines_{student_id}.txt"

with file_path.open("r") as f:
    for line in f:
        print(line.strip())
# Out:
# Line 1
# Line 2
# Line 3

# %%
from pathlib import Path

student_id = "2025-1117"
student_name = "Japhet J. Javier"

file_path = Path.home() / "Documents" / "Activity_5_Files" / f"lines_{student_id}.txt"

text = file_path.read_text()
word_count = len(text.split())

print(f"{student_name} (ID: {student_id}) - Word count: {word_count}")
# Out:
# Japhet J. Javier (ID: 2025-1117) - Word count: 6

# %%
import shutil
from pathlib import Path

student_id = "2025-1117"

documents_path = Path.home() / "Documents" / "Activity_5_Files"

src = documents_path / f"intro_{student_id}.txt"
dst = documents_path / f"intro_copy_{student_id}.txt"

shutil.copy(src, dst)

print(f"Copied {src.name} to {dst.name}")
# Out:
# Copied intro_2025-1117.txt to intro_copy_2025-1117.txt

# %%
from pathlib import Path

student_id = "2025-1117"

documents_path = Path.home() / "Documents" / "Activity_5_Files"

old_file = documents_path / f"intro_copy_{student_id}.txt"
new_file = documents_path / f"intro_renamed_{student_id}.txt"

old_file.rename(new_file)

print("File renamed successfully")
# Out:
# File renamed successfully

# %%
from pathlib import Path

student_id = "2025-1117"

file_path = Path.home() / "Documents" / "Activity_5_Files" / f"intro_renamed_{student_id}.txt"

if file_path.exists():
    file_path.unlink()
    print("File deleted successfully")
else:
    print("File not found")
# Out:
# File deleted successfully

# %%
from pathlib import Path

student_id = "2025-0907"

documents_path = Path.home() / "Documents" / "Activity_5_Files"
new_dir = documents_path / f"data_{student_id}"

new_dir.mkdir(parents=True, exist_ok=True)

print("Directory created")
# Out:
# Directory created

# %%
import json
from pathlib import Path

student_id = "2025-1117"

documents_path = Path.home() / "Documents" / "Activity_5_Files"
data_dir = documents_path / f"data_{student_id}"
data_dir.mkdir(parents=True, exist_ok=True)

data = {
    "name": "Japhet J. Javier",
    "age": 18,
    "BS ECE 1B": "Python Programming"
}

file_path = data_dir / f"student_{student_id}.json"

with file_path.open("w") as f:
    json.dump(data, f, indent=4)

print("JSON created")
# Out:
# JSON created

# %%
import json
from pathlib import Path

student_id = "2025-1117"

file_path = Path.home() / "Documents" / "Activity_5_Files" / f"data_{student_id}" / f"student_{student_id}.json"

with file_path.open("r") as f:
    data = json.load(f)

print(data)
# Out:
# {'name': 'Japhet J. Javier', 'age': 18, 'BS ECE 1B': 'Python Programming'}

# %%
import csv
from pathlib import Path

student_id = "2025-1117"
student_name = "Japhet J. Javier"

documents_path = Path.home() / "Documents" / "Activity_5_Files"
file_path = documents_path / f"students_{student_id}.csv"

rows = [
    ["Name", "TUPM-25-1117", "Score"],
    ["Anna", "2025-1001", 90],
    ["Ben", "2025-1002", 85],
    [student_name, student_id, 95]
]

with file_path.open("w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(rows)

print("CSV created")
# Out:
# CSV created

# %%
import csv
from pathlib import Path

student_id = "2025-1117"

file_path = Path.home() / "Documents" / "Activity_5_Files" / f"students_{student_id}.csv"

with file_path.open("r") as f:
    reader = csv.reader(f)
    for row in reader:
        print(row)
# Out:
# ['Name', 'TUPM-25-1117', 'Score']
# ['Anna', '2025-1001', '90']
# ['Ben', '2025-1002', '85']
# ['Japhet J. Javier', '2025-1117', '95']

# %%
from pathlib import Path

student_id = "2025-0907"

file_path = Path.home() / "Documents" / "Activity_5_Files" / f"missing_file_{student_id}.txt"

try:
    print(file_path.read_text())
except FileNotFoundError:
    print("File not found")
# Out:
# File not found

# %%
from pathlib import Path

student_id = "2025-1117"

documents_path = Path.home() / "Documents" / "Activity_5_Files"

txt_files = list(documents_path.glob("*.txt"))

print(len(txt_files))
for file in txt_files:
    print(file.name)
# Out:
# 2
# intro_2025-1117.txt
# lines_2025-1117.txt

# %%
import time
from pathlib import Path

student_id = "2025-1117"

file_path = Path.home() / "Documents" / "Activity_5_Files" / f"intro_{student_id}.txt"

if file_path.exists():
    stat = file_path.stat()
    print("Size:", stat.st_size, "bytes")
    print("Modified:", time.ctime(stat.st_mtime))
# Out:
# Size: 79 bytes
# Modified: Wed Apr 15 16:03:03 2026

# %%
from pathlib import Path

student_id = "2025-1117"

file_path = Path.home() / "Documents" / "Activity_5_Files" / f"lines_{student_id}.txt"

if not file_path.exists():
    file_path.write_text("Line 1\nLine 2\nLine 3")

lines = file_path.read_text().splitlines()

with file_path.open("w") as f:
    for i, line in enumerate(lines, 1):
        f.write(f"{i}: {line.upper()}\n")

print("Updated")
# Out:
# Updated

# %%
from pathlib import Path

student_id = "2025-1117"

file_path = Path.home() / "Documents" / "Activity_5_Files" / f"lines_{student_id}.txt"

lines = file_path.read_text().splitlines()
lines.reverse()

with file_path.open("w") as f:
    f.write("\n".join(lines))

print("Reversed")
# Out:
# Reversed

# %%
from pathlib import Path

student_id = "2025-1117"

documents_path = Path.home() / "Documents" / "Activity_5_Files"

f1 = documents_path / f"intro_{student_id}.txt"
f2 = documents_path / f"lines_{student_id}.txt"
merged = documents_path / f"merged_{student_id}.txt"

if not f1.exists():
    f1.write_text("Welcome to File Handling")

if not f2.exists():
    f2.write_text("Line 1\nLine 2\nLine 3")

with merged.open("w") as mf:
    mf.write(f1.read_text())
    mf.write("\n")
    mf.write(f2.read_text())

print("Files merged")
# Out:
# Files merged
